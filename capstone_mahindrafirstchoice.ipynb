# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaaviya1995/Kaaviya/blob/master/capstone_mahindrafirstchoice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
import io
import pandas as pd
df = pd.read_excel('/content/Customer_Data.xlsx')
df.head(10)
# Dataset is now stored in a Pandas Dataframe
# Out:
#   Business Partner CustomerNo  ...        Date of Birth Death date
# 0               31          1  ...                  NaN        NaT
# 1               32          2  ...                  NaN        NaT
# 2               34          4  ...                  NaN        NaT
# 3               35          5  ...                  NaN        NaT
# 4               42          7  ...                  NaN        NaT
# 5               45          9  ...                  NaN        NaT
# 6               46         10  ...                  NaN        NaT
# 7               47         11  ...                  NaN        NaT
# 8               49         13  ...  1981-05-18 00:00:00        NaT
# 9               50         14  ...                  NaN        NaT
#
# [10 rows x 9 columns]

# %%
import pandas as pd
df2 = pd.read_csv('/content/Final_invoice.csv')
df2.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (9,10,14,15,21,41,51) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    Index no  Amt Rcvd From Custom  ...  Total Value  User ID
# 0         0                   0.0  ...      4051.95  BC01FS1
# 1         1                   0.0  ...      1001.29  BC01SA2
# 2         2                   0.0  ...       233.14  BC01SA2
# 3         3                   0.0  ...         0.00  BC01SA2
# 4         4                   0.0  ...      2747.12  BC01SA2
# 5         5                   0.0  ...       865.92  BC01SA2
# 6         6                   0.0  ...       749.42  BC01SA2
# 7         7                   0.0  ...         0.00  BC01SA2
# 8         8                   0.0  ...         0.00  BC01SA1
# 9         9                   0.0  ...      3912.61  BC01SA1
#
# [10 rows x 59 columns]

# %%
import pandas as pd
df1 = pd.read_excel('/content/Plant Master.xlsx')
df1.head(10)
# Out:
#   Plant                          Name 1  ... Sales organization          State
# 0  BC07                      NERKUNDRAM  ...               MFCS     Tamil Nadu
# 1  BC30              SAS NAGAR - MOHALI  ...               MFCS         Punjab
# 2  X001       X001 - AUTO PLANET WHEELS  ...               MFCA    Maharashtra
# 3  X002  X002 - BHANDARI INDUSTRIES PVT  ...               MFCA  Uttar Pradesh
# 4  X003  X003 - Om Sri Satya Sai Automo  ...               MFCB      Karnataka
# 5  X005               X005 - KLN MOTORS  ...               MFCB     Tamil Nadu
# 6  X006               X006 - A.M.MOTORS  ...               MFCB    Maharashtra
# 7  X007  X007 - OM SRI SATYA SAI AUTOMO  ...               MFCB      Karnataka
# 8  X008  X008- AAKASH AUTO (Puducherry)  ...               MFCC     Puducherry
# 9  X010               X010 - LVM MOTORS  ...               MFCD     Tamil Nadu
#
# [10 rows x 13 columns]

# %%
#Total plants statewise & citywise
plan_split=df1.groupby(['State','City']).agg({'Plant':'count'})
plan_split.reset_index(inplace=True)
plan_split
# Out:
#               State          City  Plant
# 0    Andhra Pradesh     Anantapur      1
# 1    Andhra Pradesh        Guntur      1
# 2    Andhra Pradesh        Kadapa      1
# 3    Andhra Pradesh      Kakinada      1
# 4    Andhra Pradesh       Kurnool      1
# ..              ...           ...    ...
# 354     West Bengal       Kolkata      6
# 355     West Bengal     Midnapore      1
# 356     West Bengal  South Dumdum      1
# 357     West Bengal     Srirampur      1
# 358     West Bengal      Titagarh      1
#
# [359 rows x 3 columns]

# %%
#Total plants statewise
plan_split_statewise=df1.groupby(['State']).agg({'Plant':'count'})
plan_split_statewise.plot(kind='bar',figsize=(10,7))

# %%
#No of cars city wise
most_no_of_cars_city=df2.groupby(['Pin code']).size().reset_index(name='counts')
most_no_of_cars_city.plot(kind='bar')

# %%
#No fo cars localitywise
most_no_of_cars=df2.groupby(['District','Pin code']).size().reset_index(name='counts')
most_no_of_cars.head(120)
# Out:
#            District  Pin code  counts
# 0    Andhra Pradesh       0.0       4
# 1    Andhra Pradesh      10.0       1
# 2    Andhra Pradesh  145632.0       1
# 3    Andhra Pradesh  233102.0       3
# 4    Andhra Pradesh  233103.0       4
# ..              ...       ...     ...
# 115  Andhra Pradesh  501505.0       3
# 116  Andhra Pradesh  501510.0       6
# 117  Andhra Pradesh  502001.0       4
# 118  Andhra Pradesh  502032.0      74
# 119  Andhra Pradesh  502033.0       1
#
# [120 rows x 3 columns]

# %%
#No of cars statewise
most_no_of_cars=df2.groupby(['District']).size().reset_index(name='counts')
most_no_of_cars
# Out:
#                 District  counts
# 0         Andhra Pradesh    6592
# 1      Arunachal Pradesh      14
# 2                  Bihar       2
# 3             Chandigarh     944
# 4           Chhattisgarh     196
# 5   Dadra and Nagar Hav.     187
# 6          Daman and Diu     109
# 7                  Delhi    1554
# 8                    Goa       4
# 9                Gujarat    4074
# 10               Haryana    3782
# 11      Himachal Pradesh     205
# 12     Jammu and Kashmir       6
# 13             Jharkhand       7
# 14             Karnataka    5682
# 15                Kerala     651
# 16           Lakshadweep       1
# 17        Madhya Pradesh     486
# 18           Maharashtra   26031
# 19               Manipur       1
# 20              Megalaya       4
# 21              Nagaland       3
# 22            Puducherry     574
# 23                Punjab    6517
# 24             Rajasthan      29
# 25                Sikkim       1
# 26            Tamil Nadu   26372
# 27             Telangana    1516
# 28               Tripura       2
# 29         Uttar Pradesh    6769
# 30           Uttarakhand      62
# 31           West Bengal       2

# %%
#Popular car across each state
popular_car_across_tamilnadu=df2.groupby(['District']).get_group('Tamil Nadu').groupby(['Make']).size().reset_index(name='Frequency')
popular_car_across_tamilnadu.plot(kind='bar')
tickvalues=range(0,len(popular_car_across_tamilnadu['Make']))
plt.xticks(ticks=tickvalues,labels=popular_car_across_tamilnadu['Make'])
plt.title("Famous Make across Tamilnadu")
popular_car_across_maharashtra=df2.groupby(['District']).get_group('Maharashtra').groupby(['Make']).size().reset_index(name='Frequency')
popular_car_across_maharashtra.plot(kind='bar')
tickvalues=range(0,len(popular_car_across_maharashtra['Make']))
plt.xticks(ticks=tickvalues,labels=popular_car_across_maharashtra['Make'])
plt.title("Famous Make across Maharashtra")
popular_car_across_Karnataka=df2.groupby(['District']).get_group('Karnataka').groupby(['Make']).size().reset_index(name='Frequency')
popular_car_across_Karnataka.plot(kind='bar')
tickvalues=range(0,len(popular_car_across_Karnataka['Make']))
plt.xticks(ticks=tickvalues,labels=popular_car_across_Karnataka['Make'])
plt.title("Famous Make across Karnataka")
# Out:
# Text(0.5, 1.0, 'Famous Make across Karnataka')

# %%
#Famous OrderType Across Every State
popular_Order_Type_across_tamilnadu=df2.groupby(['District']).get_group('Tamil Nadu').groupby(['Order Type']).size().reset_index(name='Frequency')
popular_Order_Type_across_tamilnadu.plot(kind='bar')
tickvalues=range(0,len(popular_Order_Type_across_tamilnadu['Order Type']))
plt.xticks(ticks=tickvalues,labels=popular_Order_Type_across_tamilnadu['Order Type'])
plt.title("Famous Order Type across Tamilnadu")
popular_Order_Type_across_maharashtra=df2.groupby(['District']).get_group('Maharashtra').groupby(['Order Type']).size().reset_index(name='Frequency')
popular_Order_Type_across_maharashtra.plot(kind='bar')
tickvalues=range(0,len(popular_Order_Type_across_maharashtra['Order Type']))
plt.xticks(ticks=tickvalues,labels=popular_Order_Type_across_maharashtra['Order Type'])
plt.title("Famous Order Type across Maharashtra")
popular_Order_Type_across_Karnataka=df2.groupby(['District']).get_group('Karnataka').groupby(['Order Type']).size().reset_index(name='Frequency')
popular_Order_Type_across_Karnataka.plot(kind='bar')
tickvalues=range(0,len(popular_Order_Type_across_Karnataka['Order Type']))
plt.xticks(ticks=tickvalues,labels=popular_Order_Type_across_Karnataka['Order Type'])
plt.title("Famous Order Type across Karnataka")
# Out:
# Text(0.5, 1.0, 'Famous Order Type across Karnataka')

# %%
#Car split up across state
import matplotlib.pyplot as plt
totalcars=most_no_of_cars['counts']
districts=most_no_of_cars['District']
totalcars.plot(kind='bar',figsize=(10,7))
plt.xlabel("state")
plt.ylabel("Counts")
plt.title("Total number of cars splitup for every state")
tickvalues=range(0,len(most_no_of_cars['District']))
plt.xticks(ticks=tickvalues,labels=districts)
#plt.xticklabels(districts)
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb5a8e07b8>,
#   <matplotlib.axis.XTick at 0x7fcb5a8e0780>,
#   <matplotlib.axis.XTick at 0x7fcb5a8f9b00>,
#   <matplotlib.axis.XTick at 0x7fcb5a8cd860>,
#   <matplotlib.axis.XTick at 0x7fcb5a8cdcc0>,
#   <matplotlib.axis.XTick at 0x7fcb5a858198>,
#   <matplotlib.axis.XTick at 0x7fcb5a858630>,
#   <matplotlib.axis.XTick at 0x7fcb5a858ac8>,
#   <matplotlib.axis.XTick at 0x7fcb5a858f60>,
#   <matplotlib.axis.XTick at 0x7fcb5a8e03c8>,
#   <matplotlib.axis.XTick at 0x7fcb5a860828>,
#   <matplotlib.axis.XTick at 0x7fcb5a860cc0>,
#   <matplotlib.axis.XTick at 0x7fcb5a865198>,
#   <matplotlib.axis.XTick at 0x7fcb5a865630>,
#   <matplotlib.axis.XTick at 0x7fcb5a865ac8>,
#   <matplotlib.axis.XTick at 0x7fcb5a865f60>,
#   <matplotlib.axis.XTick at 0x7fcb5a86d438>,
#   <matplotlib.axis.XTick at 0x7fcb5a86d8d0>,
#   <matplotlib.axis.XTick at 0x7fcb5a86dd68>,
#   <matplotlib.axis.XTick at 0x7fcb5a86d9b0>,
#   <matplotlib.axis.XTick at 0x7fcb5a865780>,
#   <matplotlib.axis.XTick at 0x7fcb5a860908>,
#   <matplotlib.axis.XTick at 0x7fcb5a876278>,
#   <matplotlib.axis.XTick at 0x7fcb5a876710>,
#   <matplotlib.axis.XTick at 0x7fcb5a876ba8>,
#   <matplotlib.axis.XTick at 0x7fcb5a8800f0>,
#   <matplotlib.axis.XTick at 0x7fcb5a880518>,
#   <matplotlib.axis.XTick at 0x7fcb5a8809b0>,
#   <matplotlib.axis.XTick at 0x7fcb5a880e48>,
#   <matplotlib.axis.XTick at 0x7fcb5a880f28>,
#   <matplotlib.axis.XTick at 0x7fcb5a876b70>,
#   <matplotlib.axis.XTick at 0x7fcb5a865588>],
#  [Text(0, 0, 'Andhra Pradesh'),
#   Text(0, 0, 'Arunachal Pradesh'),
#   Text(0, 0, 'Bihar'),
#   Text(0, 0, 'Chandigarh'),
#   Text(0, 0, 'Chhattisgarh'),
#   Text(0, 0, 'Dadra and Nagar Hav.'),
#   Text(0, 0, 'Daman and Diu'),
#   Text(0, 0, 'Delhi'),
#   Text(0, 0, 'Goa'),
#   Text(0, 0, 'Gujarat'),
#   Text(0, 0, 'Haryana'),
#   Text(0, 0, 'Himachal Pradesh'),
#   Text(0, 0, 'Jammu and Kashmir'),
#   Text(0, 0, 'Jharkhand'),
#   Text(0, 0, 'Karnataka'),
#   Text(0, 0, 'Kerala'),
#   Text(0, 0, 'Lakshadweep'),
#   Text(0, 0, 'Madhya Pradesh'),
#   Text(0, 0, 'Maharashtra'),
#   Text(0, 0, 'Manipur'),
#   Text(0, 0, 'Megalaya'),
#   Text(0, 0, 'Nagaland'),
#   Text(0, 0, 'Puducherry'),
#   Text(0, 0, 'Punjab'),
#   Text(0, 0, 'Rajasthan'),
#   Text(0, 0, 'Sikkim'),
#   Text(0, 0, 'Tamil Nadu'),
#   Text(0, 0, 'Telangana'),
#   Text(0, 0, 'Tripura'),
#   Text(0, 0, 'Uttar Pradesh'),
#   Text(0, 0, 'Uttarakhand'),
#   Text(0, 0, 'West Bengal')])

# %%
#popular car across country
popular_car_make = df2.groupby('Make').size()
popular_car_make_for_every_dist=df2.groupby(['District','Make']).size()
popular_car_make
# Out:
# Make
# AUDI                       36
# BMW                        45
# DAEWOO                     56
# FIAT                     1021
# FORCE                      27
# FORD                     3957
# GENERAL MOTORS           6853
# HINDUSTAN MOTORS           39
# HONDA                    2600
# HYUNDAI                 17062
# LAND ROVER                  3
# MAHINDRA &  MAHINDRA    15456
# MARUTI SUZUKI           27003
# MERCEDES BENZ              45
# MITSUBISHI MOTORS         211
# NISSAN                    507
# PORCHE                      2
# PREMIER AUTOMOBILES         9
# RENAULT                   417
# SKODA                    1089
# SONALIKA                    5
# TATA MOTORS             11314
# TOYOTA                   3488
# VOLKSWAGEN               1131
# VOLVO                       3
# dtype: int64

# %%
popular_car_make.plot(kind='bar')
plt.ylabel("No of cars for every make")
plt.title("popular car make across country")
# Out:
# Text(0.5, 1.0, 'popular car make across country')

# %%
import pandas as pd
df3 = pd.read_csv('/content/JTD.csv')
df3.head(10)
# Out:
#    Unnamed: 0  DBM Order  ...  Target quantity UoM Net value
# 0           0      22385  ...                  MIN   1869.87
# 1           1      23910  ...                   EA   2151.13
# 2           2      23910  ...                   EA   2552.92
# 3           3      23910  ...                   EA  20360.14
# 4           4      23910  ...                   EA  10691.63
# 5           5      23910  ...                   EA   1155.56
# 6           6      23910  ...                   EA   1827.57
# 7           7      23910  ...                  MIN   3379.98
# 8           8      23910  ...                  MIN   5880.97
# 9           9      23910  ...                  MIN   1099.99
#
# [10 rows x 10 columns]

# %%
#popular machine parts
revenue_machinparts=df3.groupby(['Item Category']).size().reset_index(name='Counts')
revenue_machinparts.head()
# Out:
#   Item Category  Counts
# 0          G2TX    8651
# 1          P001  341293
# 2          P002  597718
# 3          P010   33249
# 4          P011   67664

# %%
revenue_machinparts.plot(kind='bar')
plt.xticks(ticks=revenue_machinparts.index,labels=revenue_machinparts['Item Category'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb583f5780>,
#   <matplotlib.axis.XTick at 0x7fcb583f5748>,
#   <matplotlib.axis.XTick at 0x7fcb5839bf28>,
#   <matplotlib.axis.XTick at 0x7fcb583a6358>,
#   <matplotlib.axis.XTick at 0x7fcb583a6828>],
#  [Text(0, 0, 'G2TX'),
#   Text(0, 0, 'P001'),
#   Text(0, 0, 'P002'),
#   Text(0, 0, 'P010'),
#   Text(0, 0, 'P011')])

# %%
famous_servicetype_statewise=df2.groupby(['District','Order Type']).size().reset_index(name='Frequency')
famous_servicetype_statewise.head(10)
famous_servicetype_statewise.get_group('Maharashtra')
ordertype=famous_servicetype_statewise['Order Type']
district=famous_servicetype_statewise['District']
counts=famous_servicetype_statewise['Frequency']
ax=famous_servicetype_statewise.hist(column=['District','Frequency'],by=ordertype,figsize=(20,25),bins=40)
ax.xticks(ticks=famous_servicetype_statewise.index,labels=district)
ax.yticks(ticks=famous_servicetype_statewise.index,labels=counts)

# %%
#popular Order Type among Top 3 car make
popular_service_type_maruti=df2.groupby(['Make']).get_group('MARUTI SUZUKI').groupby(['Order Type']).size().reset_index(name='Famous Frequency')
popular_service_type_maruti.plot(kind='bar')
tickvalues=range(0,len(popular_service_type_maruti['Order Type']))
plt.xticks(ticks=tickvalues,labels=popular_service_type_maruti['Order Type'])
plt.title("Famous Order Type for Maruti")
popular_service_type_Mahindra=df2.groupby(['Make']).get_group('MAHINDRA &  MAHINDRA').groupby(['Order Type']).size().reset_index(name='Famous Frequency')
popular_service_type_Mahindra.plot(kind='bar')
tickvalues=range(0,len(popular_service_type_Mahindra['Order Type']))
plt.xticks(ticks=tickvalues,labels=popular_service_type_Mahindra['Order Type'])
plt.title("Famous Order Type for Mahindra")
popular_service_type_Hyundai=df2.groupby(['Make']).get_group('HYUNDAI').groupby(['Order Type']).size().reset_index(name='Famous Frequency')
popular_service_type_Hyundai.plot(kind='bar')
tickvalues=range(0,len(popular_service_type_Hyundai['Order Type']))
plt.xticks(ticks=tickvalues,labels=popular_service_type_Hyundai['Order Type'])
plt.title("Famous Order Type for Hyundai")
# Out:
# Text(0.5, 1.0, 'Famous Order Type for Hyundai')

# %%
famous_servicetype_statewise=df2.groupby(['District','Order Type']).size().reset_index(name='Frequency')
famous_servicetype_statewise.head(10)
famous_servicetype_statewise
# Out:
#                  District       Order Type  Frequency
# 0    Andaman and Nico.In.       Accidental          2
# 1    Andaman and Nico.In.     Paid Service          1
# 2    Andaman and Nico.In.  Running Repairs          5
# 3          Andhra Pradesh       Accidental       4311
# 4          Andhra Pradesh       Mechanical        830
# ..                    ...              ...        ...
# 196           Uttarakhand        WBW Order          2
# 197           West Bengal       Accidental         76
# 198           West Bengal       Mechanical         21
# 199           West Bengal     Paid Service        193
# 200           West Bengal  Running Repairs        957
#
# [201 rows x 3 columns]

# %%
#Famous service Type
famous_servicetype=df2.groupby(['Order Type']).size().reset_index(name='Frequency')
famous_servicetype.plot(kind='bar')
plt.title("Famoue service type")
plt.xlabel("Service type")
plt.ylabel("Frequency")
order_type=famous_servicetype['Order Type']
plt.xticks(ticks=famous_servicetype.index,labels=order_type,rotation = 'vertical')
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6dc28da0>,
#   <matplotlib.axis.XTick at 0x7fcb6dc28d68>,
#   <matplotlib.axis.XTick at 0x7fcb6dd87470>,
#   <matplotlib.axis.XTick at 0x7fcb6dd87668>,
#   <matplotlib.axis.XTick at 0x7fcb6dd87d30>,
#   <matplotlib.axis.XTick at 0x7fcb6dd87550>,
#   <matplotlib.axis.XTick at 0x7fcb6dd75400>,
#   <matplotlib.axis.XTick at 0x7fcb6dc289b0>,
#   <matplotlib.axis.XTick at 0x7fcb6dd77160>],
#  [Text(0, 0, 'Accidental'),
#   Text(0, 0, 'Mechanical'),
#   Text(0, 0, 'Paid Service'),
#   Text(0, 0, 'Repeat Order'),
#   Text(0, 0, 'Running Repairs'),
#   Text(0, 0, 'SMC Redemption'),
#   Text(0, 0, 'SMC Value Package'),
#   Text(0, 0, 'WBW Order'),
#   Text(0, 0, 'Workshop Damage')])

# %%
popularservice_for_everymake = df2.groupby(['Make','Order Type']).size().reset_index(name='Counts')
carmake=popularservice_for_everymake['Make']
carmake.drop_duplicates(inplace=False)
ordertype=popularservice_for_everymake['Order Type']
ordertype
popularservice_for_everymake.plot(x='Make',y='Counts',kind='bar')
#popularservice_for_everymake['Order Type']=Series(range(len(popularservice_for_everymake)))
#popularservice_for_everymake.plot(x='Make',y='Order Type')

# %%
#Merge JTD and Invoice
jtd_invoice=pd.merge(df2,df3,left_on=df2['Index no'],right_on=df3['DBM Order'],how='outer')
jtd_invoice
# Out:
#           key_0  Index no  ...  Target quantity UoM  Net value
# 0             0       0.0  ...                  NaN        NaN
# 1             1       1.0  ...                  NaN        NaN
# 2             2       2.0  ...                  NaN        NaN
# 3             3       3.0  ...                  NaN        NaN
# 4             4       4.0  ...                  NaN        NaN
# ...         ...       ...  ...                  ...        ...
# 1414553  559151       NaN  ...                  MIN    5692.99
# 1414554  559151       NaN  ...                  MIN   11762.99
# 1414555  559151       NaN  ...                  MIN   10049.99
# 1414556  559621       NaN  ...                  NaN       0.00
# 1414557  559776       NaN  ...                  NaN       0.00
#
# [1414558 rows x 70 columns]

# %%
#Merge JTD,Invoice and customer
jtd_invoice_customer=pd.merge(df,jtd_invoice,on='CustomerNo',how='outer')
jtd_invoice_customer_cleaned=jtd_invoice_customer.dropna(subset=['Total Value','Net value'])
jtd_invoice_customer.head(10)
# Out:
#   Business Partner CustomerNo  ...  Target quantity UoM Net value
# 0               31          1  ...                  NaN       NaN
# 1               32          2  ...                  NaN       NaN
# 2               34          4  ...                  NaN       NaN
# 3               35          5  ...                  NaN       NaN
# 4               42          7  ...                  NaN       NaN
# 5               45          9  ...                  NaN       NaN
# 6               46         10  ...                  NaN       NaN
# 7               47         11  ...                  NaN       NaN
# 8               49         13  ...                  NaN       NaN
# 9               50         14  ...                  NaN       NaN
#
# [10 rows x 78 columns]

# %%
#Total revenue for generated by customer

Totalrevenue=jtd_invoice_customer_cleaned['Total Value']+jtd_invoice_customer_cleaned['Net value']
Totalrevenue
# Out:
# 551480     1253.81
# 551481     1997.97
# 551482     2105.77
# 551483     1253.42
# 551484     1096.47
#             ...
# 1398411    7438.10
# 1398412    5327.91
# 1398413    5578.20
# 1398414    5435.02
# 1398415       1.70
# Length: 561202, dtype: float64

# %%
#Add Total revenue to cleaned dataframe
jtd_invoice_customer_cleaned['Total_revenue']=Totalrevenue
jtd_invoice_customer_cleaned.head(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#        Business Partner CustomerNo  ...  Net value Total_revenue
# 551480           E10007     E10007  ...     170.04       1253.81
# 551481           E10007     E10007  ...     914.20       1997.97
# 551482           E10007     E10007  ...    1022.00       2105.77
# 551483           E10013     E10013  ...     252.13       1253.42
# 551484           E10013     E10013  ...      95.18       1096.47
#
# [5 rows x 79 columns]

# %%
#Total  revenue for every Make
revenue_per_make=jtd_invoice_customer_cleaned.groupby(['Make']).agg({'Total_revenue':'sum'})
revenue_per_make.plot(kind='bar',figsize=(10,7))

# %%
#Revenue state wise
revenue_per_state=jtd_invoice_customer_cleaned.groupby(['District']).agg({'Total_revenue':'sum'})
revenue_per_state.plot(kind='bar',figsize=(10,7))

# %%
revenue_per_city=jtd_invoice_customer_cleaned.groupby(['CITY']).agg({'Total_revenue':'sum'})
revenue_per_city
# Out:
#        Total_revenue
# CITY
# THANE   2.844191e+09

# %%
#Top 20 Materials for Running Repairs
Running_repairs_materials=jtd_invoice_customer_cleaned.groupby(['Order Type']).get_group('Running Repairs').groupby('Material').size().reset_index(name='Counts')
Running_repairs_materials.nlargest(20,['Counts'])
# Out:
#                 Material  Counts
# 29821   MARUTISUZUKI_SRV   17997
# 29842         MISC_SRV07   14552
# 29820       MAHINDRA_SRV   12371
# 29777        HYUNDAI_SRV    9460
# 28594       FFSOIL200901    8240
# 31009     TATAMOTORS_SRV    6197
# 28169        FFPRMFOL005    4744
# 27940           ACCT_SRV    3649
# 28338           FFSCO230    3142
# 29271  GENERALMOTORS_SRV    2976
# 28577       FFSOIL101034    2820
# 28162        FFPRMFLB002    2486
# 29269           FORD_SRV    2250
# 30886          PAINT_SRV    2187
# 28329           FFSCO215    2017
# 28327           FFSCO213    1957
# 4685      1AM99000M99027    1941
# 28328           FFSCO214    1937
# 28161        FFPRMFLB001    1833
# 28330           FFSCO216    1805

# %%
#Clustering Using Kmeans to obtain Revenue patterns
#Pivot table creation for revenue
table=pd.pivot_table(jtd_invoice_customer_cleaned,values=['Total_revenue'],index=['District','Make','Model'],
               aggfunc={'Total_revenue':'sum','Make':'count'})
#table.head(25)
table.nlargest(20,['Total_revenue'])
# Out:
#                                                    Make  Total_revenue
# District       Make                 Model
# Tamil Nadu     MAHINDRA &  MAHINDRA SCORPIO CRDE   7679    74088144.17
# Maharashtra    MAHINDRA &  MAHINDRA SCORPIO CRDE   9526    59023767.74
# Tamil Nadu     MAHINDRA &  MAHINDRA XYLO           6859    58514000.52
# Maharashtra    MARUTI SUZUKI        SWIFT         10650    49357230.63
# Tamil Nadu     TATA MOTORS          INDICA         8892    47938042.71
#                HYUNDAI              SANTRO         8182    41394857.48
#                MAHINDRA &  MAHINDRA BOLERO         5431    41176650.23
#                MARUTI SUZUKI        SWIFT          7383    37000067.86
# Maharashtra    MARUTI SUZUKI        WAGONR        10313    33310261.82
#                HYUNDAI              SANTRO         9120    32137348.88
# Tamil Nadu     MAHINDRA &  MAHINDRA LOGAN D        3639    31355520.84
#                HYUNDAI              I10            5476    29406759.62
# Maharashtra    MAHINDRA &  MAHINDRA XYLO           4450    28570702.86
#                MARUTI SUZUKI        ALTO           8809    27876238.97
#                HONDA                CITY           5124    26351869.31
#                TATA MOTORS          INDICA         6531    25565409.94
#                HYUNDAI              I10            6667    24140485.95
# Tamil Nadu     MARUTI SUZUKI        ALTO           5756    23964275.39
#                FORD                 FIESTA         3321    23296837.66
# Andhra Pradesh TATA MOTORS          VISTA          3872    23138491.85

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
X=jtd_invoice_customer_cleaned[['District','Make','Total_revenue']].copy()
cluster = KMeans(n_clusters=5, init='k-means++', max_iter=300, n_init=10,random_state=0)
kmeans = cluster.fit(X)
centroids = kmeans.cluster_centers_
print(centroids)
plt.scatter(X['District'],Y['Total_revenue'],c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()

# %%
#Clustering using KMEANS
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
#jtd_invoice_customer_cleaned[['District','Make','Total_revenue']].copy()
cluster = KMeans(n_clusters=7, init='k-means++', max_iter=300, n_init=10,random_state=0)
kmeans = cluster.fit(table)
centroids = kmeans.cluster_centers_
print(centroids)
wcss=kmeans.inertia_
print(wcss)
# Out:
# [[5.70797428e+01 2.39358232e+05]
#  [5.40200000e+03 2.58249761e+07]
#  [1.57480000e+03 7.50057918e+06]
#  [8.02133333e+03 6.38753041e+07]
#  [2.51581818e+03 1.42226005e+07]
#  [5.63595960e+02 2.89070784e+06]
#  [8.10760000e+03 4.33733698e+07]]
# 1289637129946003.0

# %%
#Elbow method for number of clusters
dist=[]

for k in range(1,15):

    # Initialize KMeans algorithm
    kmeans = KMeans(n_clusters=k,init='k-means++', max_iter=300, n_init=10, random_state=0)
    # Fit on data
    kmeans.fit(table)
    # Append WCSS to list storing WCSS
    dist.append(kmeans.inertia_)
    plt.figure(figsize=(10,10))

# Line plot # clusters on X-axis and WCSS on Y-axis 
plt.plot(range(1,15),dist)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
import numpy as np;
#Make=table['Make']
plt.scatter(x=table['Make'],y=table['Total_revenue'],c= kmeans.labels_.astype(float), s=50, alpha=0.5)
#plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
#ticks=table.index,labels=Make
plt.show()

# %%
import scipy.cluster.hierarchy as sch
fig, ax_1 = plt.subplots(figsize=(20,40))
# dendrogram with "ward" linkage
dend  = sch.dendrogram(sch.linkage(table, method='ward'), leaf_rotation=90, ax=ax_1)

# plot on a figure
ax_1.set_title("Dendrogram")
ax_1.set_xlabel('Revenue')
ax_1.set_ylabel('euclidean')
plt.show()

# %%
#Labour/Service Costing
jtd_invoice_customer_cleaned.head(4)
labourservicecost = (jtd_invoice_customer_cleaned['Total Value']-jtd_invoice_customer_cleaned['Labour Total'])
jtd_invoice_customer_cleaned['labourservicecost']= labourservicecost
jtd_invoice_customer_cleaned.head(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#        Business Partner CustomerNo  ...  Total_revenue labourservicecost
# 551480           E10007     E10007  ...        1253.81            573.80
# 551481           E10007     E10007  ...        1997.97            573.80
# 551482           E10007     E10007  ...        2105.77            573.80
# 551483           E10013     E10013  ...        1253.42            197.03
# 551484           E10013     E10013  ...        1096.47            197.03
#
# [5 rows x 80 columns]

# %%
#labour/Service costing for every Make
#fig, ax = plt.subplots(figsize=(15,7))
Labourservicecost_for_make=jtd_invoice_customer_cleaned.groupby(['Make']).agg({'labourservicecost':'sum'})
#revenue_per_state=jtd_invoice_customer_cleaned.groupby(['District']).agg({'Total_revenue':'sum'})
#make=Labourservicecost_for_make['Model']
#labourcost=Labourservicecost_for_make['labour/service cost']
#Labourservicecost_for_make.plot(kind='bar')
Labourservicecost_for_make.plot(kind='bar',figsize=(10,7))

# %%
#Labour total for each make
Labourservicecost_for_make=jtd_invoice_customer_cleaned.groupby(['Make']).agg({'Labour Total':'sum'})
Labourservicecost_for_make.plot(kind='bar',figsize=(10,7))

# %%
#Making customer segments
customer_segments=jtd_invoice_customer.groupby(['Data Origin']).agg({'Total Value':'sum'})
customer_segments.head(10)
customer_segments.plot(kind='line')

# %%
#Revenue based on cust type

customer_type=jtd_invoice_customer_cleaned.groupby(['Cust Type']).agg({'Total Value':'sum'})
customer_type.plot(kind='bar')

# %%
#Revenue baased on order type
Revenue_order_type=jtd_invoice_customer_cleaned.groupby(['District','Order Type']).agg({'Total_revenue':'sum'})
Revenue_order_type
# Out:
#                                       Total_revenue
# District             Order Type
# Andaman and Nico.In. Accidental        3.394529e+04
#                      Running Repairs   1.072128e+05
# Andhra Pradesh       Accidental        1.086914e+08
#                      Paid Service      9.703630e+07
#                      Repeat Order      3.115333e+04
# ...                                             ...
# Uttarakhand          Paid Service      1.271472e+05
#                      Running Repairs   1.112625e+05
# West Bengal          Accidental        4.184000e+03
#                      Paid Service      1.064018e+04
#                      Running Repairs   9.955600e+02
#
# [128 rows x 1 columns]

# %%
#order tyoe for each state
Order_type_statewise=jtd_invoice_customer_cleaned.groupby(['Order Type','District']).size().reset_index(name='Counts')
Order_type_statewise.head(30)
# Out:
#       Order Type              District  Counts
# 0     Accidental  Andaman and Nico.In.       1
# 1     Accidental        Andhra Pradesh    6740
# 2     Accidental     Arunachal Pradesh       2
# 3     Accidental                 Assam       2
# 4     Accidental                 Bihar       3
# 5     Accidental            Chandigarh     304
# 6     Accidental          Chhattisgarh     288
# 7     Accidental  Dadra and Nagar Hav.     255
# 8     Accidental         Daman and Diu     124
# 9     Accidental                 Delhi    1437
# 10    Accidental               Gujarat    2675
# 11    Accidental               Haryana    2023
# 12    Accidental      Himachal Pradesh     403
# 13    Accidental             Karnataka    4252
# 14    Accidental                Kerala     581
# 15    Accidental        Madhya Pradesh     570
# 16    Accidental           Maharashtra   12297
# 17    Accidental            Puducherry      67
# 18    Accidental                Punjab    3300
# 19    Accidental             Rajasthan      17
# 20    Accidental                Sikkim       2
# 21    Accidental            Tamil Nadu   15199
# 22    Accidental             Telangana    1010
# 23    Accidental         Uttar Pradesh    1615
# 24    Accidental           Uttarakhand       5
# 25    Accidental           West Bengal       1
# 26  Paid Service        Andhra Pradesh   15841
# 27  Paid Service     Arunachal Pradesh      12
# 28  Paid Service            Chandigarh     655
# 29  Paid Service          Chhattisgarh     564

# %%
#Customer segmentation based on revenue and comeback
repeated_users=pd.pivot_table(jtd_invoice_customer_cleaned,values=['Total_revenue'],index=['District','User ID','Invoice Date','Order Type','Make'],
               aggfunc={'Total_revenue':'sum','User ID':'count'})
repeated_users=repeated_users.rename(columns={'User ID':'Useridcomeback'})
repeated_users.reset_index(inplace=True)
golden_customers=repeated_users.loc[(repeated_users['Useridcomeback']>20)]
golden_customers_revenue=golden_customers.groupby(['User ID']).agg({'Total_revenue':'sum'})
golden_customers_revenue
loyal_customers=repeated_users.loc[(repeated_users['Useridcomeback']>10)&(repeated_users['Useridcomeback']<=20)]
loyal_customers_revenue=loyal_customers.groupby(['User ID']).agg({'Total_revenue':'sum'})
loyal_customers_revenue
avg_customers=repeated_users.loc[(repeated_users['Useridcomeback']>5)&(repeated_users['Useridcomeback']<=10)]
avg_customers_revenue=avg_customers.groupby(['User ID']).agg({'Total_revenue':'sum'})
avg_customers_revenue
attention_required_customers=repeated_users.loc[(repeated_users['Useridcomeback']<=5)]
attention_required_customers_revenue=attention_required_customers.groupby(['User ID']).agg({'Total_revenue':'sum'})
attention_required_customers_revenue
golden_customers_revenue_total=golden_customers_revenue['Total_revenue'].sum()
loyal_customers_revenue_total=loyal_customers_revenue['Total_revenue'].sum()
avg_customers_revenue_total=avg_customers_revenue['Total_revenue'].sum()
attention_required_customers_revenue_total=attention_required_customers_revenue['Total_revenue'].sum()
print(golden_customers_revenue_total,loyal_customers_revenue_total,avg_customers_revenue_total,attention_required_customers_revenue_total)
# Out:
# 933089530.5799999 835989920.99 556337527.2299999 518773691.19000006

# %%
#Regular customers across state
lowturnback=repeated_users.groupby(['District','Useridcomeback']).size().reset_index(name='counts')
District=lowturnback['District']
users=lowturnback['Useridcomeback']
turnback=pd.DataFrame({'district':District,'users':users})
lowturnback_users=turnback.groupby(['district']).agg({'users':'sum'})
lowturnback_users.plot(kind='bar')

# %%
#Popular make for golden customers
golden_customers_make=golden_customers.groupby(['Make']).size().reset_index(name='Frequency')
golden_customers_make.plot(kind='bar')
plt.xticks(ticks=golden_customers_make.index,labels=golden_customers_make['Make'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6fa3b5f8>,
#   <matplotlib.axis.XTick at 0x7fcb6fa3bcf8>,
#   <matplotlib.axis.XTick at 0x7fcb6e336400>,
#   <matplotlib.axis.XTick at 0x7fcb6e476320>,
#   <matplotlib.axis.XTick at 0x7fcb6e476cc0>,
#   <matplotlib.axis.XTick at 0x7fcb6e476d68>,
#   <matplotlib.axis.XTick at 0x7fcb6e4d5400>,
#   <matplotlib.axis.XTick at 0x7fcb651627f0>,
#   <matplotlib.axis.XTick at 0x7fcb6e49c518>,
#   <matplotlib.axis.XTick at 0x7fcb6e331630>,
#   <matplotlib.axis.XTick at 0x7fcb6e474940>,
#   <matplotlib.axis.XTick at 0x7fcb6e3449e8>,
#   <matplotlib.axis.XTick at 0x7fcb6e48ab70>,
#   <matplotlib.axis.XTick at 0x7fcb6e331828>,
#   <matplotlib.axis.XTick at 0x7fcb6e331400>,
#   <matplotlib.axis.XTick at 0x7fcb6e340ac8>,
#   <matplotlib.axis.XTick at 0x7fcb6e340cf8>,
#   <matplotlib.axis.XTick at 0x7fcb6e4c6470>,
#   <matplotlib.axis.XTick at 0x7fcb6e4c65f8>,
#   <matplotlib.axis.XTick at 0x7fcb6e4c0470>,
#   <matplotlib.axis.XTick at 0x7fcb6e4c0710>],
#  [Text(0, 0, 'AUDI'),
#   Text(0, 0, 'BMW'),
#   Text(0, 0, 'DAEWOO'),
#   Text(0, 0, 'FIAT'),
#   Text(0, 0, 'FORCE'),
#   Text(0, 0, 'FORD'),
#   Text(0, 0, 'GENERAL MOTORS'),
#   Text(0, 0, 'HINDUSTAN MOTORS'),
#   Text(0, 0, 'HONDA'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'MAHINDRA &  MAHINDRA'),
#   Text(0, 0, 'MARUTI SUZUKI'),
#   Text(0, 0, 'MERCEDES BENZ'),
#   Text(0, 0, 'MITSUBISHI MOTORS'),
#   Text(0, 0, 'NISSAN'),
#   Text(0, 0, 'PREMIER\xa0AUTOMOBILES'),
#   Text(0, 0, 'RENAULT'),
#   Text(0, 0, 'SKODA'),
#   Text(0, 0, 'TATA MOTORS'),
#   Text(0, 0, 'TOYOTA'),
#   Text(0, 0, 'VOLKSWAGEN')])

# %%
#popular order Type for golden customers
golden_customers_ordertype=golden_customers.groupby(['Order Type']).size().reset_index(name='Frequency')
golden_customers_ordertype.plot(kind='bar')
plt.xticks(ticks=golden_customers_ordertype.index,labels=golden_customers_ordertype['Order Type'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6e4c8c50>,
#   <matplotlib.axis.XTick at 0x7fcb6e4c8ba8>,
#   <matplotlib.axis.XTick at 0x7fcb66d3d400>,
#   <matplotlib.axis.XTick at 0x7fcb66d3dcf8>,
#   <matplotlib.axis.XTick at 0x7fcb66d3d1d0>,
#   <matplotlib.axis.XTick at 0x7fcb66e32cf8>],
#  [Text(0, 0, 'Accidental'),
#   Text(0, 0, 'Paid Service'),
#   Text(0, 0, 'Repeat Order'),
#   Text(0, 0, 'Running Repairs'),
#   Text(0, 0, 'SMC Redemption'),
#   Text(0, 0, 'SMC Value Package')])

# %%
#Popular make for loyal customers
loyal_customers_make=loyal_customers.groupby(['Make']).size().reset_index(name='Frequency')
loyal_customers_make.plot(kind='bar')
plt.xticks(ticks=loyal_customers_make.index,labels=loyal_customers_make['Make'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb66dc5c50>,
#   <matplotlib.axis.XTick at 0x7fcb66dc5f98>,
#   <matplotlib.axis.XTick at 0x7fcb6b21ec18>,
#   <matplotlib.axis.XTick at 0x7fcb6b254400>,
#   <matplotlib.axis.XTick at 0x7fcb6b244b00>,
#   <matplotlib.axis.XTick at 0x7fcb62016278>,
#   <matplotlib.axis.XTick at 0x7fcb5b082240>,
#   <matplotlib.axis.XTick at 0x7fcb66dc4898>,
#   <matplotlib.axis.XTick at 0x7fcb55bf35c0>,
#   <matplotlib.axis.XTick at 0x7fcb55bd6320>,
#   <matplotlib.axis.XTick at 0x7fcb55bf3470>,
#   <matplotlib.axis.XTick at 0x7fcb55bd64e0>,
#   <matplotlib.axis.XTick at 0x7fcb6b254358>,
#   <matplotlib.axis.XTick at 0x7fcb58352b00>,
#   <matplotlib.axis.XTick at 0x7fcb58352f60>,
#   <matplotlib.axis.XTick at 0x7fcb66d2ebe0>,
#   <matplotlib.axis.XTick at 0x7fcb66d2e390>,
#   <matplotlib.axis.XTick at 0x7fcb66d2e400>,
#   <matplotlib.axis.XTick at 0x7fcb6fab8080>,
#   <matplotlib.axis.XTick at 0x7fcb6fab8da0>,
#   <matplotlib.axis.XTick at 0x7fcb66d2e048>,
#   <matplotlib.axis.XTick at 0x7fcb58352978>,
#   <matplotlib.axis.XTick at 0x7fcb66d2e208>],
#  [Text(0, 0, 'AUDI'),
#   Text(0, 0, 'BMW'),
#   Text(0, 0, 'DAEWOO'),
#   Text(0, 0, 'FIAT'),
#   Text(0, 0, 'FORCE'),
#   Text(0, 0, 'FORD'),
#   Text(0, 0, 'GENERAL MOTORS'),
#   Text(0, 0, 'HINDUSTAN MOTORS'),
#   Text(0, 0, 'HONDA'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'MAHINDRA &  MAHINDRA'),
#   Text(0, 0, 'MARUTI SUZUKI'),
#   Text(0, 0, 'MERCEDES BENZ'),
#   Text(0, 0, 'MITSUBISHI MOTORS'),
#   Text(0, 0, 'NISSAN'),
#   Text(0, 0, 'PREMIER\xa0AUTOMOBILES'),
#   Text(0, 0, 'RENAULT'),
#   Text(0, 0, 'SAN MOTORS'),
#   Text(0, 0, 'SKODA'),
#   Text(0, 0, 'SONALIKA'),
#   Text(0, 0, 'TATA MOTORS'),
#   Text(0, 0, 'TOYOTA'),
#   Text(0, 0, 'VOLKSWAGEN')])

# %%
#popular order Type for Loyal customers
loyal_customers_ordertype=loyal_customers.groupby(['Order Type']).size().reset_index(name='Frequency')
loyal_customers_ordertype.plot(kind='bar')
plt.xticks(ticks=loyal_customers_ordertype.index,labels=loyal_customers_ordertype['Order Type'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6f67b908>,
#   <matplotlib.axis.XTick at 0x7fcb6f67b8d0>,
#   <matplotlib.axis.XTick at 0x7fcb6f6545c0>,
#   <matplotlib.axis.XTick at 0x7fcb6f6547b8>,
#   <matplotlib.axis.XTick at 0x7fcb6f654e80>,
#   <matplotlib.axis.XTick at 0x7fcb6f63a358>],
#  [Text(0, 0, 'Accidental'),
#   Text(0, 0, 'Paid Service'),
#   Text(0, 0, 'Repeat Order'),
#   Text(0, 0, 'Running Repairs'),
#   Text(0, 0, 'SMC Redemption'),
#   Text(0, 0, 'SMC Value Package')])

# %%
#Popular make for attention required customers
attention_required_customers_make=attention_required_customers.groupby(['Make']).size().reset_index(name='Frequency')
attention_required_customers_make.plot(kind='bar',figsize=(10,7))
plt.xticks(ticks=attention_required_customers_make.index,labels=attention_required_customers['Make'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6f5cdd30>,
#   <matplotlib.axis.XTick at 0x7fcb6f5cdcf8>,
#   <matplotlib.axis.XTick at 0x7fcb6f562940>,
#   <matplotlib.axis.XTick at 0x7fcb6f562b38>,
#   <matplotlib.axis.XTick at 0x7fcb6f598240>,
#   <matplotlib.axis.XTick at 0x7fcb6f5986d8>,
#   <matplotlib.axis.XTick at 0x7fcb6f598b70>,
#   <matplotlib.axis.XTick at 0x7fcb6f5150b8>,
#   <matplotlib.axis.XTick at 0x7fcb6f5cd940>,
#   <matplotlib.axis.XTick at 0x7fcb6f515898>,
#   <matplotlib.axis.XTick at 0x7fcb6f515d30>,
#   <matplotlib.axis.XTick at 0x7fcb6f506208>,
#   <matplotlib.axis.XTick at 0x7fcb6f5066a0>,
#   <matplotlib.axis.XTick at 0x7fcb6f506b38>,
#   <matplotlib.axis.XTick at 0x7fcb6f506d68>,
#   <matplotlib.axis.XTick at 0x7fcb6f4f04a8>,
#   <matplotlib.axis.XTick at 0x7fcb6f4f0940>,
#   <matplotlib.axis.XTick at 0x7fcb6f4f0dd8>,
#   <matplotlib.axis.XTick at 0x7fcb6f4f0198>,
#   <matplotlib.axis.XTick at 0x7fcb6f5062e8>,
#   <matplotlib.axis.XTick at 0x7fcb6f515630>,
#   <matplotlib.axis.XTick at 0x7fcb6f5194a8>,
#   <matplotlib.axis.XTick at 0x7fcb6f519940>,
#   <matplotlib.axis.XTick at 0x7fcb6f519dd8>,
#   <matplotlib.axis.XTick at 0x7fcb6f4e42b0>],
#  [Text(0, 0, 'MAHINDRA &  MAHINDRA'),
#   Text(0, 0, 'TOYOTA'),
#   Text(0, 0, 'MAHINDRA &  MAHINDRA'),
#   Text(0, 0, 'TATA MOTORS'),
#   Text(0, 0, 'TOYOTA'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'MITSUBISHI MOTORS'),
#   Text(0, 0, 'TATA MOTORS'),
#   Text(0, 0, 'HONDA'),
#   Text(0, 0, 'FIAT'),
#   Text(0, 0, 'HONDA'),
#   Text(0, 0, 'TOYOTA'),
#   Text(0, 0, 'MARUTI SUZUKI'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'MAHINDRA &  MAHINDRA'),
#   Text(0, 0, 'TOYOTA'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'FORD'),
#   Text(0, 0, 'MARUTI SUZUKI'),
#   Text(0, 0, 'HONDA'),
#   Text(0, 0, 'MARUTI SUZUKI'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'TATA MOTORS')])

# %%
#Popular make for Avg customers
avg_customers_customers_make=avg_customers.groupby(['Make']).size().reset_index(name='Frequency')
avg_customers_customers_make.plot(kind='bar',figsize=(10,7))
plt.xticks(ticks=avg_customers_customers_make.index,labels=avg_customers_customers_make['Make'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6f4c0e80>,
#   <matplotlib.axis.XTick at 0x7fcb6f4c0e48>,
#   <matplotlib.axis.XTick at 0x7fcb6f263400>,
#   <matplotlib.axis.XTick at 0x7fcb6f2635f8>,
#   <matplotlib.axis.XTick at 0x7fcb6f263cc0>,
#   <matplotlib.axis.XTick at 0x7fcb6f297198>,
#   <matplotlib.axis.XTick at 0x7fcb6f297630>,
#   <matplotlib.axis.XTick at 0x7fcb6f4c0a90>,
#   <matplotlib.axis.XTick at 0x7fcb6f27f630>,
#   <matplotlib.axis.XTick at 0x7fcb6f27fac8>,
#   <matplotlib.axis.XTick at 0x7fcb6f297a90>,
#   <matplotlib.axis.XTick at 0x7fcb6f263898>,
#   <matplotlib.axis.XTick at 0x7fcb6f27f588>,
#   <matplotlib.axis.XTick at 0x7fcb6f271198>,
#   <matplotlib.axis.XTick at 0x7fcb6f271630>,
#   <matplotlib.axis.XTick at 0x7fcb6f271ac8>,
#   <matplotlib.axis.XTick at 0x7fcb6f271f60>,
#   <matplotlib.axis.XTick at 0x7fcb6f295438>,
#   <matplotlib.axis.XTick at 0x7fcb6f2958d0>,
#   <matplotlib.axis.XTick at 0x7fcb6f295d68>,
#   <matplotlib.axis.XTick at 0x7fcb6f295390>,
#   <matplotlib.axis.XTick at 0x7fcb6f2714a8>,
#   <matplotlib.axis.XTick at 0x7fcb6f263518>],
#  [Text(0, 0, 'AUDI'),
#   Text(0, 0, 'BMW'),
#   Text(0, 0, 'DAEWOO'),
#   Text(0, 0, 'FIAT'),
#   Text(0, 0, 'FORCE'),
#   Text(0, 0, 'FORD'),
#   Text(0, 0, 'GENERAL MOTORS'),
#   Text(0, 0, 'HINDUSTAN MOTORS'),
#   Text(0, 0, 'HONDA'),
#   Text(0, 0, 'HYUNDAI'),
#   Text(0, 0, 'MAHINDRA &  MAHINDRA'),
#   Text(0, 0, 'MARUTI SUZUKI'),
#   Text(0, 0, 'MERCEDES BENZ'),
#   Text(0, 0, 'MITSUBISHI MOTORS'),
#   Text(0, 0, 'NISSAN'),
#   Text(0, 0, 'PREMIER\xa0AUTOMOBILES'),
#   Text(0, 0, 'RENAULT'),
#   Text(0, 0, 'SKODA'),
#   Text(0, 0, 'SONALIKA'),
#   Text(0, 0, 'TATA MOTORS'),
#   Text(0, 0, 'TOYOTA'),
#   Text(0, 0, 'VOLKSWAGEN'),
#   Text(0, 0, 'VOLVO')])

# %%
#Popular ordertype for Avg customers customers
avg_customers_ordertype=avg_customers.groupby(['Order Type']).size().reset_index(name='Frequency')
avg_customers_ordertype.plot(kind='bar')
plt.xticks(ticks=avg_customers_ordertype.index,labels=avg_customers_ordertype['Order Type'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6f256da0>,
#   <matplotlib.axis.XTick at 0x7fcb6f256d68>,
#   <matplotlib.axis.XTick at 0x7fcb6f186a58>,
#   <matplotlib.axis.XTick at 0x7fcb6f186c18>,
#   <matplotlib.axis.XTick at 0x7fcb6f197358>,
#   <matplotlib.axis.XTick at 0x7fcb6f1977f0>],
#  [Text(0, 0, 'Accidental'),
#   Text(0, 0, 'Paid Service'),
#   Text(0, 0, 'Repeat Order'),
#   Text(0, 0, 'Running Repairs'),
#   Text(0, 0, 'SMC Redemption'),
#   Text(0, 0, 'SMC Value Package')])

# %%
#Popular ordertype for attention required customers
attention_required_customers_ordertype=attention_required_customers.groupby(['Order Type']).size().reset_index(name='Frequency')
attention_required_customers_ordertype.plot(kind='bar')
plt.xticks(ticks=attention_required_customers_ordertype.index,labels=attention_required_customers['Order Type'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6f16f9b0>,
#   <matplotlib.axis.XTick at 0x7fcb6f16f320>,
#   <matplotlib.axis.XTick at 0x7fcb6f0e07b8>,
#   <matplotlib.axis.XTick at 0x7fcb6f0e09b0>,
#   <matplotlib.axis.XTick at 0x7fcb6f105128>,
#   <matplotlib.axis.XTick at 0x7fcb6f105550>,
#   <matplotlib.axis.XTick at 0x7fcb6f1059e8>],
#  [Text(0, 0, 'Accidental'),
#   Text(0, 0, 'Running Repairs'),
#   Text(0, 0, 'Accidental'),
#   Text(0, 0, 'SMC Value Package'),
#   Text(0, 0, 'Accidental'),
#   Text(0, 0, 'Paid Service'),
#   Text(0, 0, 'Paid Service')])

# %%
#Plot the customer revenue over segments
data=[['Golden Customers',golden_customers_revenue_total],['Loyal Customers',loyal_customers_revenue_total],['Average Custoers',avg_customers_revenue_total],['Attention needed customers',attention_required_customers_revenue_total]]
Customer_segmentation_revenue=pd.DataFrame(data,columns=['Customer Type','Revenue'])
Customer_segmentation_revenue.plot(kind='bar')
plt.xticks(ticks=Customer_segmentation_revenue.index,labels=Customer_segmentation_revenue['Customer Type'])
# Out:
# ([<matplotlib.axis.XTick at 0x7fcb6ef582b0>,
#   <matplotlib.axis.XTick at 0x7fcb6ef581d0>,
#   <matplotlib.axis.XTick at 0x7fcb6ef227b8>,
#   <matplotlib.axis.XTick at 0x7fcb6ef229b0>],
#  [Text(0, 0, 'Golden Customers'),
#   Text(0, 0, 'Loyal Customers'),
#   Text(0, 0, 'Average Custoers'),
#   Text(0, 0, 'Attention needed customers')])

# %%
Customer_segmentation_revenue
# Out:
#                 Customer Type       Revenue
# 0            Golden Customers  9.330895e+08
# 1             Loyal Customers  8.359899e+08
# 2            Average Custoers  5.563375e+08
# 3  Attention needed customers  5.187737e+08

# %%
#Inventory Management
df3.head(10)
Hightest_inventory=jtd_invoice_customer_cleaned.groupby(['Item Category','Material','District','Make']).size().reset_index(name='Count')
Hightest_inventory
# Out:
#        Item Category   Material        District                  Make  Count
# 0               P001  ACCTBP001      Tamil Nadu                TOYOTA      1
# 1               P001  ACCTBP002  Andhra Pradesh        GENERAL MOTORS      1
# 2               P001  ACCTBP002  Andhra Pradesh         MARUTI SUZUKI      3
# 3               P001  ACCTBP002         Gujarat                 HONDA      1
# 4               P001  ACCTBP002         Haryana                  FORD      1
# ...              ...        ...             ...                   ...    ...
# 182700          P011    RECO001   Uttar Pradesh               HYUNDAI     10
# 182701          P011    RECO001   Uttar Pradesh  MAHINDRA &  MAHINDRA      3
# 182702          P011    RECO001   Uttar Pradesh         MARUTI SUZUKI     12
# 182703          P011    RECO001   Uttar Pradesh                NISSAN      2
# 182704          P011    RECO001   Uttar Pradesh           TATA MOTORS      4
#
# [182705 rows x 5 columns]

# %% [markdown]
# # New Section
